# %% [markdown]
# - lh, rh, both for [fsaverage, fsaverage5, 164k_fs_LR, 32k_fs_LR]
# - with and without medial wall
# - Plot full cifti w/ subcort
# - All for parcellation or stat map

# %%
from neurotools.plotting import plot
import numpy as np
# Out:
# /home/sage/anaconda3/envs/bpt/lib/python3.9/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %% [markdown]
# ### Test 1 - Plot fs_LR_32k single hemispheres
#
# Make sure that the symmetric_bar option works also.

# %%
plot(np.random.random(32492), hemi='lh', symmetric_cbar=False)
plot(np.random.random(32492), hemi='rh', symmetric_cbar=True)

# %% [markdown]
# ### Test 2 - Plot fs_LR_32k both hemispheres - collage
#
# Make sure that the symmetric_bar option works also.

# %%
plot(np.random.random(32492 * 2))
plot(np.random.random(32492 * 2), symmetric_cbar=True)

# %% [markdown]
# ### Test 3 - Plot fs_LR_32k single hemispheres parcellation

# %%
plot(np.random.randint(10, size=32492), hemi='lh')
plot(np.random.randint(10, size=32492), hemi='rh')

# %% [markdown]
# ### Test 4 - Plot fs_LR_32k both hemispheres - collage parcellations

# %%
d = np.random.randint(10, size=32492)
plot([d, d])
plot(np.concatenate([d, d]))

# %% [markdown]
# ### Test plot base parc

# %%
plot(np.random.randint(10, size=91282), figsize=((9, 12)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-b2bd0477a43a> in <module>
# ----> 1 plot(np.random.randint(10, size=91282), figsize=((9, 12)))
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot(data, space, hemi, verbose, **kwargs)
#     923         # Last case is vol / surf collage
#     924         else:
# --> 925             _plot_surfs_vol(data, space=None, hemi=None, rois=True,
#     926                             _print=_print, **kwargs)
#     927
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in _plot_surfs_vol(data, space, hemi, rois, cmap, vol_plot_type, surf_mesh, bg_map, colorbar, symmetric_cbar, darkness, vmin, vmax, cbar_vmin, cbar_vmax, figure, axes, subplot_spec, figsize, title, title_sz, hspace, wspace, surf_alpha, avg_method, threshold, surf_to_vol_ratio, surf_wspace, bg_on_data, _print, **kwargs)
#     747
#     748     # Pass arguments to plot surf vol collage
# --> 749     plot_surf_vol_collage(surf=[data['lh'], data['rh']],
#     750                           vol=data['sub'],
#     751                           vol_plot_type=vol_plot_type,
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot_surf_vol_collage(surf, vol, vol_plot_type, cmap, threshold, surf_to_vol_ratio, vmin, vmax, cbar_vmin, cbar_vmax, figure, axes, subplot_spec, figsize, title, title_sz, colorbar, symmetric_cbar, hspace, wspace, colorbar_params, surf_params, vol_params, verbose, _print)
#     434         vol_plot_func = plot_roi
#     435     else:
# --> 436         raise RuntimeError('vol_plot_type must be one of "glass", "stat" or "roi".')
#     437
#     438     # Handle funny case where plotting glass
#
# RuntimeError: vol_plot_type must be one of "glass", "stat" or "roi".

# %% [markdown]
# ### Test controlling surface specific wspace - plot parc

# %%
plot(np.random.randint(10, size=91282), surf_wspace=.5)

# %% [markdown]
# ### Test controlling surf to vol ratio - plot parc

# %%
plot(np.random.randint(10, size=91282), surf_to_vol_ratio=3)

# %% [markdown]
# ### Test plot non-parc collage with and w/o color bar

# %%
plot(np.random.random(91282))

# %%
plot(np.random.random(91282), colorbar=False)
