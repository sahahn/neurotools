# %% [markdown]
# - lh, rh, both for [fsaverage, fsaverage5, 164k_fs_LR, 32k_fs_LR]
# - with and without medial wall
# - Plot full cifti w/ subcort
# - All for parcellation or stat map

# %%
from neurotools.plotting import plot
import numpy as np
# Out:
# /home/sage/anaconda3/envs/bpt/lib/python3.9/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
plot(np.random.random(32492), hemi='lh')
plot(np.random.random(32492), hemi='rh')
plot(np.random.random(32492 * 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-e9fb8b7802e2> in <module>
#       1 plot(np.random.random(32492), hemi='lh')
#       2 plot(np.random.random(32492), hemi='rh')
# ----> 3 plot(np.random.random(32492 * 2))
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot(data, space, hemi, **kwargs)
#     596         plot_surf_parc(data, space=space, hemi=hemi, **kwargs)
#     597     else:
# --> 598         plot_surf(data, space=space, hemi=hemi, **kwargs)
#     599
#     600
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot_surf(data, space, hemi, surf_mesh, bg_map, cmap, bg_on_data, darkness, avg_method, wspace, hspace, alpha, symmetric_cbar, threshold, colorbar, **kwargs)
#     456     # Both hemi's passed case.
#     457     if data[0] is not None and data[1] is not None:
# --> 458         plot_surf_collage(data=data, ref=ref,
#     459                           surf_mesh=surf_mesh,
#     460                           bg_map=bg_map,
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot_surf_collage(data, ref, surf_mesh, bg_map, view, title, title_sz, vmin, vmax, cbar_vmin, cbar_vmax, figsize, figure, axes, subplot_spec, wspace, hspace, colorbar, dist, colorbar_params, **kwargs)
#     219
#     220         figure, axes[i], smf =\
# --> 221             plot_surf_hemi(data=data[d], ref=ref, hemi=hemis[i],
#     222                            surf_mesh=surf_mesh, bg_map=bg_map,
#     223                            vmin=vmin, vmax=vmax, view=views[i],
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/neurotools/plotting/plot.py in plot_surf_hemi(data, ref, hemi, surf_mesh, bg_map, **kwargs)
#     131     # And colorbar limits depending on symmetric_cbar settings
#     132     cbar_vmin, cbar_vmax, vmin, vmax =\
# --> 133         _get_colorbar_and_data_ranges(data, vmax, symmetric_cbar, kwargs)
#     134
#     135     return plot_single_surf(surf_mesh=surf_mesh,
#
# ~/anaconda3/envs/bpt/lib/python3.9/site-packages/nilearn/plotting/img_plotting.py in _get_colorbar_and_data_ranges(stat_map_data, vmax, symmetric_cbar, kwargs, force_min_stat_map_value)
#      75     """
#      76     if 'vmin' in kwargs:
# ---> 77         raise ValueError('this function does not accept a "vmin" '
#      78                          'argument, as it uses a symmetrical range '
#      79                          'defined via the vmax argument. To threshold '
#
# ValueError: this function does not accept a "vmin" argument, as it uses a symmetrical range defined via the vmax argument. To threshold the plotted map, use the "threshold" argument
